# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier 
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc

# %%
###R1 - import remainingdata.csv.

df = pd.read_csv('remainingdata.csv')

#drop column id
df = df.drop(columns=['id'])
#print(df.to_string())
df
# Out:
#        loan_amount  funded_amount  funded_amount_investors  term  \
# 0              0.0            0.0                  0.00000    36
# 1           2500.0         2500.0               2500.00000    36
# 2           5000.0         5000.0               5000.00000    36
# 3           7000.0         7000.0               7000.00000    36
# 4           2000.0         2000.0               2000.00000    36
# ...            ...            ...                      ...   ...
# 34921       3000.0         3000.0               3000.00000    36
# 34922      10400.0        10400.0              10400.00000    36
# 34923      16000.0        10550.0              10531.35818    60
# 34924      10000.0        10000.0              10000.00000    36
# 34925       3200.0         3200.0               3200.00000    36
#
#        interest_rate  installment  employment_length  home_ownership  \
# 0               0.00         0.00                  1               4
# 1              13.98        85.42                  4               4
# 2              15.95       175.67                  4               4
# 3               9.91       225.58                 10               0
# 4               5.42        60.32                 10               4
# ...              ...          ...                ...             ...
# 34921          11.99        99.63                  3               4
# 34922          13.49       352.88                  9               4
# 34923          14.96       250.77                 10               0
# 34924          16.89       355.99                  1               4
# 34925          13.49       108.58                  7               4
#
#        annual_income  verification_status  ...  public_records  \
# 0                0.0                    1  ...             0.0
# 1            20004.0                    1  ...             0.0
# 2            59000.0                    1  ...             0.0
# 3            53796.0                    1  ...             0.0
# 4            30000.0                    1  ...             0.0
# ...              ...                  ...  ...             ...
# 34921        74250.0                    0  ...             0.0
# 34922        62000.0                    2  ...             0.0
# 34923        95088.0                    2  ...             1.0
# 34924        48720.0                    1  ...             0.0
# 34925        38400.0                    2  ...             1.0
#
#        revolving_balance  revolving_utillization  no_total_account  \
# 0                    0.0                     0.0               1.0
# 1                  981.0                    21.3              10.0
# 2                18773.0                    99.9              15.0
# 3                 3269.0                    47.2              20.0
# 4                    0.0                     0.0              15.0
# ...                  ...                     ...               ...
# 34921            16550.0                    73.5              22.0
# 34922            16898.0                    39.7              33.0
# 34923            10386.0                    62.2              25.0
# 34924             7301.0                    53.3              12.0
# 34925             2503.0                    62.6              18.0
#
#        total_payment  total_payment_investors  total_received_principal  \
# 0           0.000000                     0.00                      0.00
# 1        3075.291779                  3075.29                   2500.00
# 2        2948.760000                  2948.76                   1909.02
# 3        8082.391880                  8082.39                   7000.00
# 4        2161.663244                  2161.66                   2000.00
# ...              ...                      ...                       ...
# 34921    3586.619764                  3586.62                   3000.00
# 34922   12703.534030                 12703.53                  10400.00
# 34923   14202.267530                 14163.31                  10550.00
# 34924   12815.178320                 12815.18                  10000.00
# 34925    3908.767275                  3908.77                   3200.00
#
#        total_received_interest  last_payment_amnt  repay_fail
# 0                         0.00               0.00           1
# 1                       575.29              90.85           0
# 2                       873.81             175.67           1
# 3                      1082.39            1550.27           0
# 4                       161.66              53.12           0
# ...                        ...                ...         ...
# 34921                   586.62             100.30           0
# 34922                  2303.53             393.08           0
# 34923                  3652.27            5439.96           0
# 34924                  2815.18             380.63           0
# 34925                   708.77             111.88           0
#
# [34926 rows x 26 columns]

# %%
###R2 - count how repay_fail variable (0 and 1) to see if the data balance or not.

Count_repay_fail = df['repay_fail'].value_counts()
print(Count_repay_fail)

df["repay_fail"].value_counts(dropna=False).plot(kind="pie")
# Out:
# repay_fail
# 0    29836
# 1     5090
# Name: count, dtype: int64
# <Axes: ylabel='count'>

# %%
###R3 - Downsample the majority class to match the number of samples in the minority class - balance the data


from sklearn.utils import resample

minority_class = df[df['repay_fail'] == 1 ]
majority_class = df[df['repay_fail'] == 0 ]

# Downsample the majority class
majority_downsampled = resample(majority_class, replace=False, n_samples=len(minority_class), random_state=42)

# Combine the downsampled majority class with the minority class
df = pd.concat([minority_class, majority_downsampled])

# %%
df["repay_fail"].value_counts(dropna=False).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
Count_repay_fail = df['repay_fail'].value_counts()
print(Count_repay_fail)
# Out:
# repay_fail
# 1    5090
# 0    5090
# Name: count, dtype: int64

# %%
###R4 - drop features that is has low relationships between two variables; no linear relationship between the variables  
# by referring to heatmap in R5.

df = df.drop(columns=['no_delinquency_2yrs', 'employment_length', 'purpose', 'debt_to_income_ratio', 'inquiries_last_6mths'
                      , 'public_records' , 'home_ownership' , 'verification_status', 'revolving_balance', 'annual_income'
                      , 'term', 'revolving_utillization', 'no_open_accounts', 'no_total_account', 'interest_rate', 'last_payment_amnt'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10180 entries, 0 to 24194
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_amount               10180 non-null  float64
#  1   funded_amount             10180 non-null  float64
#  2   funded_amount_investors   10180 non-null  float64
#  3   installment               10180 non-null  float64
#  4   loan_status               10180 non-null  int64
#  5   total_payment             10180 non-null  float64
#  6   total_payment_investors   10180 non-null  float64
#  7   total_received_principal  10180 non-null  float64
#  8   total_received_interest   10180 non-null  float64
#  9   repay_fail                10180 non-null  int64
# dtypes: float64(8), int64(2)
# memory usage: 874.8 KB

# %%
###R5 – use heatmap; to see relationships between two variables. Observe if there are any patterns in value for one or both variables.

f,ax=plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,linewidth=.5,fmt='.1f',ax=ax)
plt.show()

# %%
###R6 - split data to train and test with test size 0.2.

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='repay_fail'), df['repay_fail'], test_size=0.20, random_state=42)

# %%
###R7 - Train the model using the training data.

model = RandomForestClassifier(max_depth=5)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
#Use the trained model to make predictions on the x_test 
y_predict = model.predict(X_test)

# %%
###R6 - evaluates the performance of a classification model using a confusion matrix and calculates the accuracy score.

cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm/np.sum(cm),annot=True,fmt=".2%",cmap='Blues')
plt.show()
ac = accuracy_score(y_test,y_predict)
print('Accuracy is: ',ac*100)
# Out:
# Accuracy is:  99.65618860510806

# %%
# Assuming y_test contains the true labels and predictions contains the predicted labels
cm = confusion_matrix(y_test, y_predict)

# Create a list of labels for each cell
label_names = [['True Negative', 'False Positive'],
               ['False Negative', 'True Positive']]

# Create a heatmap with labels inside the cells
sns.heatmap(cm,annot=True,fmt="d", cmap='Blues', cbar=False,
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])

# Add labels inside the cells
for i in range(len(label_names)):
    for j in range(len(label_names[0])):
        plt.text(j + 0.5, i + 0.4, label_names[i][j], ha='center', va='center', fontsize=10)

# Add labels to the plot
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Show the plot
plt.show()

# %%
###R7 - evaluates the performance of your classification model using a Receiver Operating Characteristic (ROC) curve

y_pred_quant = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_quant)

fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], transform=ax.transAxes, ls="--", c=".3")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve ')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
auc(fpr, tpr)
# Out:
# 0.999948810224047

# %%
###R8 - Print a detailed classification report

from sklearn.metrics import accuracy_score, classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       987
#            1       1.00      1.00      1.00      1049
#
#     accuracy                           1.00      2036
#    macro avg       1.00      1.00      1.00      2036
# weighted avg       1.00      1.00      1.00      2036

# %%
###R9 - save trained model

import pickle as cPickle
with open('modelDataBalance_9features','wb') as f:
    cPickle.dump(model,f)
